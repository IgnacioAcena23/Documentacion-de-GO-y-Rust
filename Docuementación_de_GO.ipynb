# %% [markdown]
# <a href="https://colab.research.google.com/github/IgnacioAcena23/Documentacion-de-GO-y-Rust/blob/main/Docuementaci%C3%B3n_de_GO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Configuración del entorno (Solo es necesario correrlo una vez por sesión)
import os
if not os.path.exists("/usr/local/go/bin/go"):
    print("Instalando Go...")
    # !wget https://go.dev/dl/go1.21.6.linux-amd64.tar.gz -q
    # !tar -C /usr/local -xzf go1.21.6.linux-amd64.tar.gz
    print("Go instalado.")

os.environ['PATH'] += ":/usr/local/go/bin"

# 2. Código de GO para poder correrlo en Python
with open("main.go", "w") as f:
    f.write(r"""
package main

import "fmt"

func main() {
    entradaDatos()
    sumar()
    ciclos()
    cicloWhile()
}

func sumar() float64 {
    var a float64
    var b float64
    fmt.Println("\n-----------------------------------------------------")
    fmt.Println("\t\tSuma de dos numeros")
    fmt.Println("-----------------------------------------------------")
    fmt.Print("-> Ingrese el primer numero: ")
    fmt.Scanln(&a)
    fmt.Print("-> Ingrese el segundo numero: ")
    fmt.Scanln(&b)
    suma := a + b
    fmt.Println("\nLa suma entre los dos números es igual a: ", suma)
    return suma
}

func ciclos() {
    var contar int
    fmt.Println("\n-----------------------------------------------------")
    fmt.Println("\t\t   Ciclo For")
    fmt.Println("-----------------------------------------------------")
    fmt.Print("-> Di hasta que numero quieres que cuente: ")
    fmt.Scanln(&contar)
    for i := 1; i <= contar; i++ {
        fmt.Println("* Vuelta #", i)
    }
}

func cicloWhile() {
    i := 0
    var contar int
    fmt.Println("\n-----------------------------------------------------")
    fmt.Println("\t\t   Ciclo While")
    fmt.Println("-----------------------------------------------------")
    fmt.Print("-> Diga un número para buscar en el escondite: ")
    fmt.Scanln(&contar)
    for i < contar {
        fmt.Println("* Comenzamos en:", i+1, "...")
        i++
    }
    fmt.Println("¡Listos o no alla voyyy!\n\n\t\tFin del Programa")
}

func entradaDatos() {
    var name string
    var age int
    var height float64
    var genderElect bool
    var gender string

    fmt.Println("\n----------------------------------------------------")
    fmt.Println("\t  Ingrese sus Datos Personales")
    fmt.Println("----------------------------------------------------")
    fmt.Print("-> Ingrese su nombre: ")
    fmt.Scanln(&name)
    fmt.Println("Hola", name)

    fmt.Print("-> Ingrese su edad: ")
    fmt.Scanln(&age)

    fmt.Print("-> Ingrese su altura en metros: ")
    fmt.Scanln(&height)

    fmt.Print("-> ¿Eres hombre? (true/false): ")
    fmt.Scanln(&genderElect)

    if genderElect {
        gender = "Masculino"
    } else {
        gender = "Femenino"
    }
    fmt.Println("\n----------------------------------------------------")
    fmt.Println("\tInformación personal recopilada")
    fmt.Println("----------------------------------------------------")
    fmt.Println("* Nombre: ",name)
    fmt.Println("* Edad:   ",age)
    fmt.Println("* Altura: ",height)
    fmt.Println("* Género: ",gender)
}
""")

# 3. Ejecución del código
# !go run main.go
